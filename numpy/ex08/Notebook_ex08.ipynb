# %%
import numpy as np

data = np.genfromtxt("data/winequality-red.csv", delimiter=';',dtype=np.float32)
ar2d=np.array((data[1:2],data[6:7],data[11:12]))
ar2d=data[[1,6,11]]
alcohol = data[:, -1]
result = np.any(alcohol > 20)
avg_alcohol = np.nanmean(alcohol)
print(data.nbytes)
print(ar2d)
print(result)
print(avg_alcohol)
# Out:
# 76800
# [[ 7.4     0.7     0.      1.9     0.076  11.     34.      0.9978  3.51
#    0.56    9.4     5.    ]
#  [ 7.4     0.66    0.      1.8     0.075  13.     40.      0.9978  3.51
#    0.56    9.4     5.    ]
#  [ 6.7     0.58    0.08    1.8     0.097  15.     65.      0.9959  3.28
#    0.54    9.2     5.    ]]
# False
# 5.6360226
