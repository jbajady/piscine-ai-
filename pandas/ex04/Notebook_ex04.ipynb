# %%
import numpy as np
import pandas as pd

# %%
dt = pd.read_csv("data/iris.csv")
dt = dt.drop(columns=['flower'])
print(dt.head())
# Out:
#   sepal_length sepal_width petal_length petal_width
# 0          5.1         3.5          1.4         0.2
# 1          4.9         3.0          1.4         0.2
# 2          4.7         3.2          1.3         0.2
# 3          4.6         3.1          1.5         0.2
# 4          5.0        -3.6         -1.4         0.2

# %%
dt['sepal_length'] = pd.to_numeric(dt['sepal_length'], errors='coerce')
dt['sepal_width']  = pd.to_numeric(dt['sepal_width'],  errors='coerce')
dt['petal_length'] = pd.to_numeric(dt['petal_length'], errors='coerce')
dt['petal_width']  = pd.to_numeric(dt['petal_width'],  errors='coerce')

# dt["sepal_length"] = dt["sepal_length"].fillna(dt["sepal_length"].mean())

# dt['sepal_width'] = dt['sepal_width'].fillna(dt['sepal_width'].median())


# dt['petal_length'] = dt['petal_length'].fillna(0)
# dt['petal_width']  = dt['petal_width'].fillna(0)

# print(dt.isnull().sum())  # Should print 0 for all columns ✅
dt.fillna({
        0:dt.sepal_length.mean(),
        2:dt.sepal_width.median(),
        3:0,
        4:0
    })

dt.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean      56.907534    49.648000     12.423333    11.786000
# std      564.489133   404.506037    114.078057   130.550042
# min       -4.400000    -3.600000     -4.800000    -2.500000
# 25%        5.100000     2.800000      1.300000     0.225000
# 50%        5.800000     3.000000      4.000000     1.300000
# 75%        6.500000     3.300000      4.975000     1.800000
# max     6900.000000  3809.000000   1400.000000  1600.000000
