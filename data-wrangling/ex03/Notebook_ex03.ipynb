# %%
import pandas as pd
import numpy as np
# generate days
all_dates = pd.date_range('2021-01-01', '2021-12-15')
business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

# generate tickers
tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

# create indexes
index_alt = pd.MultiIndex.from_product([all_dates, tickers], names=['Date', 'Ticker'])
index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

# create DFs
market_data = pd.DataFrame(index=index,
                        data=np.random.randn(len(index), 3),
                        columns=['Open','Close','Close_Adjusted'])

alternative_data = pd.DataFrame(index=index_alt,
                                data=np.random.randn(len(index_alt), 2),
                                columns=['Twitter','Reddit'])

dt_merge=market_data.merge(alternative_data, left_index=True, right_index=True, how='left')
res_merged = dt_merge.fillna(0)
print(res_merged.shape)
res_merged.head()
# Out:
# (1305, 5)
#                        Open     Close  Close_Adjusted   Twitter    Reddit
# Date       Ticker
# 2021-01-01 AAPL    1.830971  0.494910       -1.397706  0.081300 -0.666449
#            FB     -0.718983 -0.897274       -0.077828  1.474397 -0.217139
#            GE      0.530647 -1.302825       -0.202507  0.298705 -0.830417
#            AMZN   -0.046503 -0.032095        0.148238  0.103296  0.804153
#            DAI     0.407187  0.438177        0.542450 -0.557999 -0.857568

# %%
res_merged.sum().sum() == dt_merge.sum().sum()
# Out:
# np.True_
